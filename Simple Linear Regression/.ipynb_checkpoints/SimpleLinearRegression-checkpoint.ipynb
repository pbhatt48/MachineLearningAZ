# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#get Data
dataset = pd.read_csv('Salary_Data.csv')

# %%
#get X and Y values
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:, -1].values

# %%
#Get the split data for train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
#Call the regression functions
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

#get the prediction now
y_pred = regressor.predict(X_test)

# %%
#plot for the Train data
plt.scatter(X_train, y_train, color='blue')
plt.plot(X_train, regressor.predict(X_train), color='red')
plt.xlabel("No of years of Experience")
plt.ylabel("Salary")
plt.title("Salary Vs Years of Experience (Training Model Data)")
plt.show()

# %%
#plot for the Test data
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red')
plt.xlabel("No of years of Experience")
plt.ylabel("Salary")
plt.title("Salary Vs Years of Experience (Test Model Data)")
plt.show()
